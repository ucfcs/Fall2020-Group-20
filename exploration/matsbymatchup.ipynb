# %%
import sc2reader
from sc2reader.engine.plugins import APMTracker, ContextLoader, SelectionTracker
from sc2reader.events import *
import pandas as pd
import glob

#for replay in sc2reader.load_replays(glob.glob('../data/**/*.SC2Replay', recursive=True)):
    #print("Date: %s" % replay.date)
    #print("SC2 Version: " + replay.release_string)
    #print("Game Category: " + replay.category + " Game")
    #print("Game Type: " + replay.type)
    #print("Game Length: " + str(replay.game_length))
    #print("Map Name: " + replay.map_name)
    #for player in replay.players:
        #print("%s: %s" % (player.result, player))

# %%
#ZvZ matchups
matsZZ = []
zz = -1;

#TvT matchups
matsTT = []
tt = -1;


#PvP matchups
matsPP = []
pp = -1;

#TvZ matchups
matsTZ = []
tz = -1;

#PvZ matchups

matsPZ = []
pz = -1;

#PvT matchups
matsPT = []
pt = -1;

for replay in sc2reader.load_replays(glob.glob('../data/**/*.SC2Replay', recursive=True)):
    #ZvZ
    if replay.players[0].pick_race[0] == 'Z' and replay.players[1].pick_race[0] == 'Z':
        zz += 1
        for event in replay.events:
            if event.second % 30 == 0:
                if type(event) is PlayerStatsEvent:
                    if replay.players[0].pid == event.pid:
                        matsZZ.append([zz, event.second, replay.players[0].result, event.player, replay.players[0].pick_race[0], event.workers_active_count,
                                event.food_used, event.food_made, event.minerals_current, event.minerals_collection_rate, 
                                event.minerals_used_in_progress, event.minerals_used_current, event.minerals_used_active_forces, 
                                event.minerals_lost, event.vespene_current, event.vespene_collection_rate, 
                                event.vespene_used_in_progress, event.vespene_used_current, event.vespene_used_active_forces,
                                event.vespene_lost])
                    else:
                        matsZZ.append([zz, event.second, replay.players[1].result, event.player, replay.players[1].pick_race[0], event.workers_active_count,
                                event.food_used, event.food_made, event.minerals_current, event.minerals_collection_rate, 
                                event.minerals_used_in_progress, event.minerals_used_current, event.minerals_used_active_forces, 
                                event.minerals_lost, event.vespene_current, event.vespene_collection_rate, 
                                event.vespene_used_in_progress, event.vespene_used_current, event.vespene_used_active_forces,
                                event.vespene_lost])

    #TvT                    
    elif replay.players[0].pick_race[0] == 'T' and replay.players[1].pick_race[0] == 'T':
        tt += 1
        for event in replay.events:
            if event.second % 30 == 0:
                if type(event) is PlayerStatsEvent:
                    if replay.players[0].pid == event.pid:
                        matsTT.append([tt, event.second, replay.players[0].result, event.player, replay.players[0].pick_race[0], event.workers_active_count,
                                event.food_used, event.food_made, event.minerals_current, event.minerals_collection_rate, 
                                event.minerals_used_in_progress, event.minerals_used_current, event.minerals_used_active_forces, 
                                event.minerals_lost, event.vespene_current, event.vespene_collection_rate, 
                                event.vespene_used_in_progress, event.vespene_used_current, event.vespene_used_active_forces,
                                event.vespene_lost])
                    else:
                        matsTT.append([tt, event.second, replay.players[1].result, event.player, replay.players[1].pick_race[0], event.workers_active_count,
                                event.food_used, event.food_made, event.minerals_current, event.minerals_collection_rate, 
                                event.minerals_used_in_progress, event.minerals_used_current, event.minerals_used_active_forces, 
                                event.minerals_lost, event.vespene_current, event.vespene_collection_rate, 
                                event.vespene_used_in_progress, event.vespene_used_current, event.vespene_used_active_forces,
                                event.vespene_lost])
    
    #PvP
    elif replay.players[0].pick_race[0] == 'P' and replay.players[1].pick_race[0] == 'P':
        pp += 1
        for event in replay.events:
            if event.second % 30 == 0:
                if type(event) is PlayerStatsEvent:
                    if replay.players[0].pid == event.pid:
                        matsPP.append([pp, event.second, replay.players[0].result, event.player, replay.players[0].pick_race[0], event.workers_active_count,
                                event.food_used, event.food_made, event.minerals_current, event.minerals_collection_rate, 
                                event.minerals_used_in_progress, event.minerals_used_current, event.minerals_used_active_forces, 
                                event.minerals_lost, event.vespene_current, event.vespene_collection_rate, 
                                event.vespene_used_in_progress, event.vespene_used_current, event.vespene_used_active_forces,
                                event.vespene_lost])
                    else:
                        matsPP.append([pp, event.second, replay.players[1].result, event.player, replay.players[1].pick_race[0], event.workers_active_count,
                                event.food_used, event.food_made, event.minerals_current, event.minerals_collection_rate, 
                                event.minerals_used_in_progress, event.minerals_used_current, event.minerals_used_active_forces, 
                                event.minerals_lost, event.vespene_current, event.vespene_collection_rate, 
                                event.vespene_used_in_progress, event.vespene_used_current, event.vespene_used_active_forces,
                                event.vespene_lost])
    #TvZ
    elif (replay.players[0].pick_race[0] == 'T' and replay.players[1].pick_race[0] == 'Z') or (replay.players[0].pick_race[0] == 'Z' and replay.players[1].pick_race[0] == 'T'):
        tz += 1
        for event in replay.events:
            if event.second % 30 == 0:
                if type(event) is PlayerStatsEvent:
                    if replay.players[0].pid == event.pid:
                        matsTZ.append([tz, event.second, replay.players[0].result, event.player, replay.players[0].pick_race[0], event.workers_active_count,
                                event.food_used, event.food_made, event.minerals_current, event.minerals_collection_rate, 
                                event.minerals_used_in_progress, event.minerals_used_current, event.minerals_used_active_forces, 
                                event.minerals_lost, event.vespene_current, event.vespene_collection_rate, 
                                event.vespene_used_in_progress, event.vespene_used_current, event.vespene_used_active_forces,
                                event.vespene_lost])
                    else:
                        matsTZ.append([tz, event.second, replay.players[1].result, event.player, replay.players[1].pick_race[0], event.workers_active_count,
                                event.food_used, event.food_made, event.minerals_current, event.minerals_collection_rate, 
                                event.minerals_used_in_progress, event.minerals_used_current, event.minerals_used_active_forces, 
                                event.minerals_lost, event.vespene_current, event.vespene_collection_rate, 
                                event.vespene_used_in_progress, event.vespene_used_current, event.vespene_used_active_forces,
                                event.vespene_lost])
                        
    #PvZ
    elif (replay.players[0].pick_race[0] == 'Z' and replay.players[1].pick_race[0] == 'P') or (replay.players[0].pick_race[0] == 'P' and replay.players[1].pick_race[0] == 'Z'):
        pz += 1
        for event in replay.events:
            if event.second % 30 == 0:
                if type(event) is PlayerStatsEvent:
                    if replay.players[0].pid == event.pid:
                        matsPZ.append([pz, event.second, replay.players[0].result, event.player, replay.players[0].pick_race[0], event.workers_active_count,
                                event.food_used, event.food_made, event.minerals_current, event.minerals_collection_rate, 
                                event.minerals_used_in_progress, event.minerals_used_current, event.minerals_used_active_forces, 
                                event.minerals_lost, event.vespene_current, event.vespene_collection_rate, 
                                event.vespene_used_in_progress, event.vespene_used_current, event.vespene_used_active_forces,
                                event.vespene_lost])
                    else:
                        matsPZ.append([pz, event.second, replay.players[1].result, event.player, replay.players[1].pick_race[0], event.workers_active_count,
                                event.food_used, event.food_made, event.minerals_current, event.minerals_collection_rate, 
                                event.minerals_used_in_progress, event.minerals_used_current, event.minerals_used_active_forces, 
                                event.minerals_lost, event.vespene_current, event.vespene_collection_rate, 
                                event.vespene_used_in_progress, event.vespene_used_current, event.vespene_used_active_forces,
                                event.vespene_lost])
                        
    #PvT
    elif (replay.players[0].pick_race[0] == 'T' and replay.players[1].pick_race[0] == 'P') or (replay.players[0].pick_race[0] == 'P' and replay.players[1].pick_race[0] == 'T'):
        pt += 1
        for event in replay.events:
            if event.second % 30 == 0:
                if type(event) is PlayerStatsEvent:
                    if replay.players[0].pid == event.pid:
                        matsPT.append([pt, event.second, replay.players[0].result, event.player, replay.players[0].pick_race[0], event.workers_active_count,
                                event.food_used, event.food_made, event.minerals_current, event.minerals_collection_rate, 
                                event.minerals_used_in_progress, event.minerals_used_current, event.minerals_used_active_forces, 
                                event.minerals_lost, event.vespene_current, event.vespene_collection_rate, 
                                event.vespene_used_in_progress, event.vespene_used_current, event.vespene_used_active_forces,
                                event.vespene_lost])
                    else:
                        matsPT.append([pt, event.second, replay.players[1].result, event.player, replay.players[1].pick_race[0], event.workers_active_count,
                                event.food_used, event.food_made, event.minerals_current, event.minerals_collection_rate, 
                                event.minerals_used_in_progress, event.minerals_used_current, event.minerals_used_active_forces, 
                                event.minerals_lost, event.vespene_current, event.vespene_collection_rate, 
                                event.vespene_used_in_progress, event.vespene_used_current, event.vespene_used_active_forces,
                                event.vespene_lost])

#ZvZ                        
matsZZ_df = pd.DataFrame(matsZZ)
pd.set_option("display.max_rows", None, "display.max_columns", None)
matsZZ_df.columns = ["Match ID", "Second", "Result", "Player", "Race", "Current Workers", "Food Used", "Food Available",
                    "Current Minerals", "Minerals Collection Rate", "Minerals Used in Progress", "Minerals Used", 
                    "Minerals Used Active Forces", "Minerals Lost", "Current Vespene", "Vespene Collection Rate", 
                    "Vespene Used in Progress", "Vespene Used", "Vespene Used Active Forces", "Vespene Lost"]
matsZZ_df.to_csv(r'../Output/ZvZ.csv', index=False)
                        
#TvT                        
matsTT_df = pd.DataFrame(matsTT)
pd.set_option("display.max_rows", None, "display.max_columns", None)
matsTT_df.columns = ["Match ID", "Second", "Result", "Player", "Race", "Current Workers", "Food Used", "Food Available",
                    "Current Minerals", "Minerals Collection Rate", "Minerals Used in Progress", "Minerals Used", 
                    "Minerals Used Active Forces", "Minerals Lost", "Current Vespene", "Vespene Collection Rate", 
                    "Vespene Used in Progress", "Vespene Used", "Vespene Used Active Forces", "Vespene Lost"]
matsTT_df.to_csv(r'../Output/TvT.csv', index=False)
    
#PvP
matsPP_df = pd.DataFrame(matsPP)
pd.set_option("display.max_rows", None, "display.max_columns", None)
matsPP_df.columns = ["Match ID", "Second", "Result", "Player", "Race", "Current Workers", "Food Used", "Food Available",
                   "Current Minerals", "Minerals Collection Rate", "Minerals Used in Progress", "Minerals Used", 
                   "Minerals Used Active Forces", "Minerals Lost", "Current Vespene", "Vespene Collection Rate", 
                   "Vespene Used in Progress", "Vespene Used", "Vespene Used Active Forces", "Vespene Lost"]
matsPP_df.to_csv(r'../Output/PvP.csv', index=False)

#TvZ
matsTZ_df = pd.DataFrame(matsTZ)
pd.set_option("display.max_rows", None, "display.max_columns", None)
matsTZ_df.columns = ["Match ID", "Second", "Result", "Player", "Race", "Current Workers", "Food Used", "Food Available",
                   "Current Minerals", "Minerals Collection Rate", "Minerals Used in Progress", "Minerals Used", 
                   "Minerals Used Active Forces", "Minerals Lost", "Current Vespene", "Vespene Collection Rate", 
                   "Vespene Used in Progress", "Vespene Used", "Vespene Used Active Forces", "Vespene Lost"]
matsTZ_df.to_csv(r'../Output/TvZ.csv', index=False)

#PvZ
matsPZ_df = pd.DataFrame(matsPZ)
pd.set_option("display.max_rows", None, "display.max_columns", None)
matsPZ_df.columns = ["Match ID", "Second", "Result", "Player", "Race", "Current Workers", "Food Used", "Food Available",
                   "Current Minerals", "Minerals Collection Rate", "Minerals Used in Progress", "Minerals Used", 
                   "Minerals Used Active Forces", "Minerals Lost", "Current Vespene", "Vespene Collection Rate", 
                   "Vespene Used in Progress", "Vespene Used", "Vespene Used Active Forces", "Vespene Lost"]
matsPZ_df.to_csv(r'../Output/PvZ.csv', index=False)

#PvT
matsPT_df = pd.DataFrame(matsPT)
pd.set_option("display.max_rows", None, "display.max_columns", None)
matsPT_df.columns = ["Match ID", "Second", "Result", "Player", "Race", "Current Workers", "Food Used", "Food Available",
                   "Current Minerals", "Minerals Collection Rate", "Minerals Used in Progress", "Minerals Used", 
                   "Minerals Used Active Forces", "Minerals Lost", "Current Vespene", "Vespene Collection Rate", 
                   "Vespene Used in Progress", "Vespene Used", "Vespene Used Active Forces", "Vespene Lost"]
matsPT_df.to_csv(r'../Output/PvT.csv', index=False)
