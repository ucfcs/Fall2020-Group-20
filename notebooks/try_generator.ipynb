# %%
import sys
sys.path.append('../') # goes to project root

from preparation.generators.Generator import Generator
from IPython.display import display
import pandas as pd
import datetime
import json

pd.options.display.max_columns = None

# %%
# our Generator object requires one parameter
# grab the attr_map and load it in as a dictionary
with open('../data/functional/races.json', 'rb') as f:
    attr_map = json.load(f)

# instantiate a dataset Generator object
hr = Generator(attr_map=attr_map)

# %%
# loads replay references into memory
dfs = hr.load_replays('../data/raw/**/*.SC2Replay', limit=None)
# Out:
# Loaded 3456 replays out of 3456.

# %%
# We're storing all dataframes by key
# Keys are P, T, and Z
# These represent each race
# valid games total should always be double the number of replays since there are 2 sides to a game
dfs = hr.getData(verbose=False)
# Out:
# Skipping replay #1821 due to thrown exception.
# [Player 1 - soO (Zerg), Player 2 - HeroMarine (Terran)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 1823/3456 | Loaded  52.75% | ETA 00h24m36s Elapsed 00h27m26s
# Skipping replay #1822 due to thrown exception.
# [Player 1 - HeroMarine (Terran), Player 2 - soO (Zerg)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1822 due to thrown exception.
# [Player 1 - HeroMarine (Terran), Player 2 - soO (Zerg)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 1826/3456 | Loaded  52.84% | ETA 00h24m32s Elapsed 00h27m27s
# Skipping replay #1825 due to thrown exception.
# [Player 1 - GOStephano (Zerg), Player 2 - OGZest (Protoss)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1825 due to thrown exception.
# [Player 1 - GOStephano (Zerg), Player 2 - OGZest (Protoss)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 1839/3456 | Loaded  53.21% | ETA 00h24m16s Elapsed 00h27m34s
# Skipping replay #1838 due to thrown exception.
# [Player 1 - TYTY (Terran), Player 2 - ShoWTimE (Protoss)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1838 due to thrown exception.
# [Player 1 - TYTY (Terran), Player 2 - ShoWTimE (Protoss)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 1841/3456 | Loaded  53.27% | ETA 00h24m13s Elapsed 00h27m35s
# Skipping replay #1840 due to thrown exception.
# [Player 1 - ShoWTimE (Protoss), Player 2 - Elazer (Zerg)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1840 due to thrown exception.
# [Player 1 - ShoWTimE (Protoss), Player 2 - Elazer (Zerg)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 1842/3456 | Loaded  53.30% | ETA 00h24m12s Elapsed 00h27m35s
# Skipping replay #1841 due to thrown exception.
# [Player 1 - ShoWTimE (Protoss), Player 2 - Elazer (Zerg)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1841 due to thrown exception.
# [Player 1 - ShoWTimE (Protoss), Player 2 - Elazer (Zerg)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 1843/3456 | Loaded  53.33% | ETA 00h24m11s Elapsed 00h27m36s
# Skipping replay #1842 due to thrown exception.
# [Player 1 - HateMe (Zerg), Player 2 - TYTY (Terran)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1842 due to thrown exception.
# [Player 1 - HateMe (Zerg), Player 2 - TYTY (Terran)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 1854/3456 | Loaded  53.65% | ETA 00h23m56s Elapsed 00h27m40s
# Skipping replay #1853 due to thrown exception.
# [Player 1 - Namshar (Zerg), Player 2 - Elazer (Zerg)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1853 due to thrown exception.
# [Player 1 - Namshar (Zerg), Player 2 - Elazer (Zerg)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 1862/3456 | Loaded  53.88% | ETA 00h23m45s Elapsed 00h27m42s
# Skipping replay #1861 due to thrown exception.
# [Player 1 - ShoWTimE (Protoss), Player 2 - HellraiseR (Protoss)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1861 due to thrown exception.
# [Player 1 - ShoWTimE (Protoss), Player 2 - HellraiseR (Protoss)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 1865/3456 | Loaded  53.96% | ETA 00h23m41s Elapsed 00h27m44s
# Skipping replay #1864 due to thrown exception.
# [Player 1 - Namshar (Zerg), Player 2 - HellraiseR (Protoss)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1864 due to thrown exception.
# [Player 1 - Namshar (Zerg), Player 2 - HellraiseR (Protoss)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 1867/3456 | Loaded  54.02% | ETA 00h23m39s Elapsed 00h27m45s
# Skipping replay #1866 due to thrown exception.
# [Player 1 - Bunny (Terran), Player 2 - TYTY (Terran)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1866 due to thrown exception.
# [Player 1 - Bunny (Terran), Player 2 - TYTY (Terran)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 1871/3456 | Loaded  54.14% | ETA 00h23m33s Elapsed 00h27m46s
# Skipping replay #1870 due to thrown exception.
# [Player 1 - HateMe (Zerg), Player 2 - HellraiseR (Protoss)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1870 due to thrown exception.
# [Player 1 - HateMe (Zerg), Player 2 - HellraiseR (Protoss)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 1876/3456 | Loaded  54.28% | ETA 00h23m27s Elapsed 00h27m48s
# Skipping replay #1875 due to thrown exception.
# [Player 1 - ShoWTimE (Protoss), Player 2 - HateMe (Zerg)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1875 due to thrown exception.
# [Player 1 - ShoWTimE (Protoss), Player 2 - HateMe (Zerg)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 1885/3456 | Loaded  54.54% | ETA 00h23m16s Elapsed 00h27m53s
# Skipping replay #1884 due to thrown exception.
# [Player 1 - llllllllllll (Protoss), Player 2 - soO (Zerg)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1884 due to thrown exception.
# [Player 1 - llllllllllll (Protoss), Player 2 - soO (Zerg)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 1889/3456 | Loaded  54.66% | ETA 00h23m13s Elapsed 00h27m57s
# Skipping replay #1888 due to thrown exception.
# [Player 1 - OGZest (Protoss), Player 2 - Elazer (Zerg)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1888 due to thrown exception.
# [Player 1 - OGZest (Protoss), Player 2 - Elazer (Zerg)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 1895/3456 | Loaded  54.83% | ETA 00h23m06s Elapsed 00h28m00s
# Skipping replay #1894 due to thrown exception.
# [Player 1 - Serral (Zerg), Player 2 - TYTY (Terran)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1894 due to thrown exception.
# [Player 1 - Serral (Zerg), Player 2 - TYTY (Terran)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 1901/3456 | Loaded  55.01% | ETA 00h23m00s Elapsed 00h28m06s
# Skipping replay #1900 due to thrown exception.
# [Player 1 - TYTY (Terran), Player 2 - OGZest (Protoss)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1900 due to thrown exception.
# [Player 1 - TYTY (Terran), Player 2 - OGZest (Protoss)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 1904/3456 | Loaded  55.09% | ETA 00h22m57s Elapsed 00h28m08s
# Skipping replay #1903 due to thrown exception.
# [Player 1 - TYTY (Terran), Player 2 - OGZest (Protoss)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1903 due to thrown exception.
# [Player 1 - TYTY (Terran), Player 2 - OGZest (Protoss)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 1907/3456 | Loaded  55.18% | ETA 00h22m54s Elapsed 00h28m10s
# Skipping replay #1906 due to thrown exception.
# [Player 1 - Serral (Zerg), Player 2 - Elazer (Zerg)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1906 due to thrown exception.
# [Player 1 - Serral (Zerg), Player 2 - Elazer (Zerg)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 1909/3456 | Loaded  55.24% | ETA 00h22m55s Elapsed 00h28m14s
# Skipping replay #1908 due to thrown exception.
# [Player 1 - Serral (Zerg), Player 2 - TYTY (Terran)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1908 due to thrown exception.
# [Player 1 - Serral (Zerg), Player 2 - TYTY (Terran)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 1913/3456 | Loaded  55.35% | ETA 00h22m51s Elapsed 00h28m17s
# Skipping replay #1912 due to thrown exception.
# [Player 1 - OGZest (Protoss), Player 2 - soO (Zerg)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1912 due to thrown exception.
# [Player 1 - OGZest (Protoss), Player 2 - soO (Zerg)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 1915/3456 | Loaded  55.41% | ETA 00h22m49s Elapsed 00h28m19s
# Skipping replay #1914 due to thrown exception.
# [Player 1 - OGZest (Protoss), Player 2 - soO (Zerg)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1914 due to thrown exception.
# [Player 1 - OGZest (Protoss), Player 2 - soO (Zerg)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 1917/3456 | Loaded  55.47% | ETA 00h22m46s Elapsed 00h28m20s
# Skipping replay #1916 due to thrown exception.
# [Player 1 - Lambo (Zerg), Player 2 - OGZest (Protoss)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1916 due to thrown exception.
# [Player 1 - Lambo (Zerg), Player 2 - OGZest (Protoss)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 1924/3456 | Loaded  55.67% | ETA 00h22m39s Elapsed 00h28m25s
# Skipping replay #1923 due to thrown exception.
# [Player 1 - GOStephano (Zerg), Player 2 - HellraiseR (Protoss)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1923 due to thrown exception.
# [Player 1 - GOStephano (Zerg), Player 2 - HellraiseR (Protoss)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 1927/3456 | Loaded  55.76% | ETA 00h22m36s Elapsed 00h28m26s
# Skipping replay #1926 due to thrown exception.
# [Player 1 - GOStephano (Zerg), Player 2 - HellraiseR (Protoss)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1926 due to thrown exception.
# [Player 1 - GOStephano (Zerg), Player 2 - HellraiseR (Protoss)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 1928/3456 | Loaded  55.79% | ETA 00h22m35s Elapsed 00h28m27s
# Skipping replay #1927 due to thrown exception.
# [Player 1 - OGZest (Protoss), Player 2 - Bunny (Terran)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1927 due to thrown exception.
# [Player 1 - OGZest (Protoss), Player 2 - Bunny (Terran)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 1932/3456 | Loaded  55.90% | ETA 00h22m31s Elapsed 00h28m30s
# Skipping replay #1931 due to thrown exception.
# [Player 1 - soO (Zerg), Player 2 - TSGSolar (Zerg)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1931 due to thrown exception.
# [Player 1 - soO (Zerg), Player 2 - TSGSolar (Zerg)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 1933/3456 | Loaded  55.93% | ETA 00h22m30s Elapsed 00h28m31s
# Skipping replay #1932 due to thrown exception.
# [Player 1 - TSGSolar (Zerg), Player 2 - soO (Zerg)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1932 due to thrown exception.
# [Player 1 - TSGSolar (Zerg), Player 2 - soO (Zerg)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 1937/3456 | Loaded  56.05% | ETA 00h22m25s Elapsed 00h28m33s
# Skipping replay #1936 due to thrown exception.
# [Player 1 - Lambo (Zerg), Player 2 - llllllllllll (Protoss)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1936 due to thrown exception.
# [Player 1 - Lambo (Zerg), Player 2 - llllllllllll (Protoss)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 1943/3456 | Loaded  56.22% | ETA 00h22m17s Elapsed 00h28m35s
# Skipping replay #1942 due to thrown exception.
# [Player 1 - Elazer (Zerg), Player 2 - TSGSolar (Zerg)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1942 due to thrown exception.
# [Player 1 - Elazer (Zerg), Player 2 - TSGSolar (Zerg)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 1951/3456 | Loaded  56.45% | ETA 00h22m09s Elapsed 00h28m40s
# Skipping replay #1950 due to thrown exception.
# [Player 1 - HellraiseR (Protoss), Player 2 - TSGSolar (Zerg)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1950 due to thrown exception.
# [Player 1 - HellraiseR (Protoss), Player 2 - TSGSolar (Zerg)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 1961/3456 | Loaded  56.74% | ETA 00h22m01s Elapsed 00h28m51s
# Skipping replay #1960 due to thrown exception.
# [Player 1 - HeroMarine (Terran), Player 2 - TYTY (Terran)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1960 due to thrown exception.
# [Player 1 - HeroMarine (Terran), Player 2 - TYTY (Terran)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 1963/3456 | Loaded  56.80% | ETA 00h21m59s Elapsed 00h28m52s
# Skipping replay #1962 due to thrown exception.
# [Player 1 - HeroMarine (Terran), Player 2 - TYTY (Terran)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1962 due to thrown exception.
# [Player 1 - HeroMarine (Terran), Player 2 - TYTY (Terran)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 1965/3456 | Loaded  56.86% | ETA 00h21m57s Elapsed 00h28m53s
# Skipping replay #1964 due to thrown exception.
# [Player 1 - OGZest (Protoss), Player 2 - HeroMarine (Terran)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1964 due to thrown exception.
# [Player 1 - OGZest (Protoss), Player 2 - HeroMarine (Terran)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 1968/3456 | Loaded  56.94% | ETA 00h21m53s Elapsed 00h28m54s
# Skipping replay #1967 due to thrown exception.
# [Player 1 - Serral (Zerg), Player 2 - LiquidTLO (Zerg)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1967 due to thrown exception.
# [Player 1 - Serral (Zerg), Player 2 - LiquidTLO (Zerg)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 1977/3456 | Loaded  57.20% | ETA 00h21m41s Elapsed 00h28m57s
# Skipping replay #1976 due to thrown exception.
# [Player 1 - Serral (Zerg), Player 2 - liquidthermy (Terran)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1976 due to thrown exception.
# [Player 1 - Serral (Zerg), Player 2 - liquidthermy (Terran)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 1983/3456 | Loaded  57.38% | ETA 00h21m34s Elapsed 00h29m00s
# Skipping replay #1982 due to thrown exception.
# [Player 1 - Serral (Zerg), Player 2 - DnS (Protoss)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1982 due to thrown exception.
# [Player 1 - Serral (Zerg), Player 2 - DnS (Protoss)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 1996/3456 | Loaded  57.75% | ETA 00h21m19s Elapsed 00h29m06s
# Skipping replay #1995 due to thrown exception.
# [Player 1 - LiquidTLO (Zerg), Player 2 - DnS (Protoss)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1995 due to thrown exception.
# [Player 1 - LiquidTLO (Zerg), Player 2 - DnS (Protoss)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 2020/3456 | Loaded  58.45% | ETA 00h20m48s Elapsed 00h29m13s
# Skipping replay #2019 due to thrown exception.
# [Player 1 - liquidthermy (Terran), Player 2 - llllllllllll (Protoss)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #2019 due to thrown exception.
# [Player 1 - liquidthermy (Terran), Player 2 - llllllllllll (Protoss)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 2024/3456 | Loaded  58.56% | ETA 00h20m43s Elapsed 00h29m15s
# Skipping replay #2023 due to thrown exception.
# [Player 1 - llllllllllll (Protoss), Player 2 - DnS (Protoss)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #2023 due to thrown exception.
# [Player 1 - llllllllllll (Protoss), Player 2 - DnS (Protoss)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 2029/3456 | Loaded  58.71% | ETA 00h20m37s Elapsed 00h29m17s
# Skipping replay #2028 due to thrown exception.
# [Player 1 - llllllllllll (Protoss), Player 2 - Serral (Zerg)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #2028 due to thrown exception.
# [Player 1 - llllllllllll (Protoss), Player 2 - Serral (Zerg)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 2042/3456 | Loaded  59.09% | ETA 00h21m01s Elapsed 00h30m19s
# Skipping replay #2041 due to thrown exception.
# [Player 1 - Reynor (Zerg), Player 2 - Clem (Terran)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #2041 due to thrown exception.
# [Player 1 - Reynor (Zerg), Player 2 - Clem (Terran)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 2053/3456 | Loaded  59.40% | ETA 00h20m48s Elapsed 00h30m25s
# Skipping replay #2052 due to thrown exception.
# [Player 1 - Lambo (Zerg), Player 2 - lllIIIIllll (Protoss)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #2052 due to thrown exception.
# [Player 1 - Lambo (Zerg), Player 2 - lllIIIIllll (Protoss)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 2056/3456 | Loaded  59.49% | ETA 00h20m45s Elapsed 00h30m26s
# Skipping replay #2055 due to thrown exception.
# [Player 1 - Clem (Terran), Player 2 - Lambo (Zerg)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #2055 due to thrown exception.
# [Player 1 - Clem (Terran), Player 2 - Lambo (Zerg)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 2058/3456 | Loaded  59.55% | ETA 00h20m43s Elapsed 00h30m28s
# Skipping replay #2057 due to thrown exception.
# [Player 1 - LiquidSnute (Zerg), Player 2 - Lambo (Zerg)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #2057 due to thrown exception.
# [Player 1 - LiquidSnute (Zerg), Player 2 - Lambo (Zerg)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 2060/3456 | Loaded  59.61% | ETA 00h20m41s Elapsed 00h30m29s
# Skipping replay #2059 due to thrown exception.
# [Player 1 - Lambo (Zerg), Player 2 - Reynor (Zerg)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #2059 due to thrown exception.
# [Player 1 - Lambo (Zerg), Player 2 - Reynor (Zerg)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 2062/3456 | Loaded  59.66% | ETA 00h20m39s Elapsed 00h30m30s
# Skipping replay #2061 due to thrown exception.
# [Player 1 - lllIIIIllll (Protoss), Player 2 - Harstem (Protoss)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #2061 due to thrown exception.
# [Player 1 - lllIIIIllll (Protoss), Player 2 - Harstem (Protoss)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 2064/3456 | Loaded  59.72% | ETA 00h20m36s Elapsed 00h30m31s
# Skipping replay #2063 due to thrown exception.
# [Player 1 - Clem (Terran), Player 2 - TSGSolar (Zerg)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #2063 due to thrown exception.
# [Player 1 - Clem (Terran), Player 2 - TSGSolar (Zerg)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 2066/3456 | Loaded  59.78% | ETA 00h20m34s Elapsed 00h30m32s
# Skipping replay #2065 due to thrown exception.
# [Player 1 - Lambo (Zerg), Player 2 - A.I. 1 (Very Easy) (Protoss)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #2065 due to invalid race.
# [Player 1 - Lambo (Zerg), Player 2 - A.I. 1 (Very Easy) (Protoss)]
# Loading replay 2069/3456 | Loaded  59.87% | ETA 00h20m30s Elapsed 00h30m33s
# Skipping replay #2068 due to thrown exception.
# [Player 1 - InZaNe (Terran), Player 2 - Harstem (Protoss)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #2068 due to thrown exception.
# [Player 1 - InZaNe (Terran), Player 2 - Harstem (Protoss)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 2071/3456 | Loaded  59.92% | ETA 00h20m28s Elapsed 00h30m34s
# Skipping replay #2070 due to thrown exception.
# [Player 1 - Lambo (Zerg), Player 2 - InZaNe (Terran)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #2070 due to thrown exception.
# [Player 1 - Lambo (Zerg), Player 2 - InZaNe (Terran)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 2080/3456 | Loaded  60.19% | ETA 00h20m17s Elapsed 00h30m38s
# Skipping replay #2079 due to thrown exception.
# [Player 1 - LiquidSnute (Zerg), Player 2 - Clem (Terran)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #2079 due to thrown exception.
# [Player 1 - LiquidSnute (Zerg), Player 2 - Clem (Terran)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 2082/3456 | Loaded  60.24% | ETA 00h20m15s Elapsed 00h30m39s
# Skipping replay #2081 due to thrown exception.
# [Player 1 - LiquidSnute (Zerg), Player 2 - Reynor (Zerg)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #2081 due to thrown exception.
# [Player 1 - LiquidSnute (Zerg), Player 2 - Reynor (Zerg)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 2091/3456 | Loaded  60.50% | ETA 00h20m05s Elapsed 00h30m43s
# Skipping replay #2090 due to thrown exception.
# [Player 1 - lllIIIIllll (Protoss), Player 2 - Reynor (Zerg)]
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #2090 due to thrown exception.
# [Player 1 - lllIIIIllll (Protoss), Player 2 - Reynor (Zerg)]
# 'NoneType' object has no attribute 'lower'
# Loading replay 3456/3456 | Loaded 100.00% | ETA 00h00m03s Elapsed 01h41m22s
#
# END: Found {'P': 2308, 'T': 1984, 'Z': 2482} valid games (total=6774) out of 3456.

# %%
for k in dfs.keys():
    tmp_df = dfs[k] # grab a dataset by its player 1's race

    # go through all quantitative columns and check if their values are < 0
    # meaning it will return true if they are negative
    # then, since True == 1 and False == 0, get the result of summation per column
    negative_check = tmp_df[tmp_df.select_dtypes(exclude=['object']) < 0].sum()
    # only keep columns that are actually negative
    negative_check = negative_check[negative_check < 0]

    # this is not necessary
    # I just like how nice it looks
    col_negative_sum_zip = list(zip(negative_check.index.to_list(), negative_check.to_list()))
    if len(col_negative_sum_zip) > 0:
        col_negative_sum_zip = '\n'.join(['{} {}'.format(*n) for n in col_negative_sum_zip])
    else:
        col_negative_sum_zip = None

    print('Negative total by column for {}:\n  {}\n'.format(k, col_negative_sum_zip))
# Out:
# Negative total by column for P:
#   None
#
# Negative total by column for T:
#   orbitalcommand -83.0
#
# Negative total by column for Z:
#   None

# %%
name_map = {
    'T': 'terran',
    'P': 'protoss',
    'Z': 'zerg'
}

for k in dfs.keys():
    # get the race name by key map
    name = name_map[k]

    # only generate dataset csv if it actually contains stuff
    if len(dfs[k]) == 0:
        print('Dataframe for {} is empty, so skipping.'.format(name))
        continue

    tmp_df = dfs[k] # grab a dataset by its player 1's race

    # we're storing the number of matches stored in each dataframe
    # so, get its respective total match count by its race
    total_matches = hr.valid_matches[k]
    # create a date string for the current time and date
    date_str = datetime.datetime.now().strftime('%b-%d-%Y_%H%M%S').lower()
    # create a descriptive csv file name with:
    # - player 1's race
    # - the number of matches it contains
    # - when the dataset was generated
    filename = '{}_{}_{}'.format(name, total_matches, date_str)
    path = '../data/processed/{}.csv'.format(filename)

    print('Saving as', path)
    tmp_df.to_csv(path)
# Out:
# Saving as ../data/processed/protoss_2308_mar-05-2021_174442.csv
# Saving as ../data/processed/terran_1984_mar-05-2021_174444.csv
# Saving as ../data/processed/zerg_2482_mar-05-2021_174446.csv
