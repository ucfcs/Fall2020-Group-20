# %%
import sys
sys.path.append('..') # goes to project root

from preparation.generators.Generator import Generator
from IPython.display import display
import pandas as pd
import datetime
import json

pd.options.display.max_columns = None

# %%
# our Generator object requires one parameter
# grab the attr_map and load it in as a dictionary
with open('../data/functional/races.json', 'rb') as f:
    attr_map = json.load(f)

# instantiate a dataset Generator object
hr = Generator(attr_map=attr_map)

# %%
# loads replay references into memory
dfs = hr.load_replays('../data/raw/**/*.SC2Replay', limit=None)
# Out:
# Loaded 3456 replays out of 3456.

# %%
# We're storing all dataframes by key
# Keys are P, T, and Z
# These represent each race
# valid games total should always be double the number of replays since there are 2 sides to a game
dfs = hr.getData(verbose=False)
# Out:
# Loading replay 1477/3456 | Loaded  42.74% | Elapsed 00h22m53s
# Skipping replay #1476 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1476 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1486/3456 | Loaded  43.00% | Elapsed 00h23m05s
# Skipping replay #1485 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1485 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1491/3456 | Loaded  43.14% | Elapsed 00h23m10s
# Skipping replay #1490 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1490 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1497/3456 | Loaded  43.32% | Elapsed 00h23m16s
# Skipping replay #1496 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1496 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1770/3456 | Loaded  51.22% | Elapsed 00h27m40s
# Skipping replay #1769 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1769 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1776/3456 | Loaded  51.39% | Elapsed 00h27m44s
# Skipping replay #1775 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1775 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1780/3456 | Loaded  51.50% | Elapsed 00h27m45s
# Skipping replay #1779 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1779 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1783/3456 | Loaded  51.59% | Elapsed 00h27m47s
# Skipping replay #1782 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1782 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1792/3456 | Loaded  51.85% | Elapsed 00h27m51s
# Skipping replay #1791 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1791 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1794/3456 | Loaded  51.91% | Elapsed 00h27m51s
# Skipping replay #1793 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1793 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1795/3456 | Loaded  51.94% | Elapsed 00h27m52s
# Skipping replay #1794 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1794 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1801/3456 | Loaded  52.11% | Elapsed 00h27m54s
# Skipping replay #1800 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1800 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1806/3456 | Loaded  52.26% | Elapsed 00h27m56s
# Skipping replay #1805 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1805 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1808/3456 | Loaded  52.31% | Elapsed 00h27m57s
# Skipping replay #1807 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1807 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1815/3456 | Loaded  52.52% | Elapsed 00h28m02s
# Skipping replay #1814 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1814 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1822/3456 | Loaded  52.72% | Elapsed 00h28m05s
# Skipping replay #1821 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1821 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1823/3456 | Loaded  52.75% | Elapsed 00h28m06s
# Skipping replay #1822 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1822 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1826/3456 | Loaded  52.84% | Elapsed 00h28m07s
# Skipping replay #1825 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1825 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1839/3456 | Loaded  53.21% | Elapsed 00h28m15s
# Skipping replay #1838 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1838 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1841/3456 | Loaded  53.27% | Elapsed 00h28m16s
# Skipping replay #1840 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1840 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1842/3456 | Loaded  53.30% | Elapsed 00h28m17s
# Skipping replay #1841 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1841 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1843/3456 | Loaded  53.33% | Elapsed 00h28m17s
# Skipping replay #1842 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1842 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1854/3456 | Loaded  53.65% | Elapsed 00h28m23s
# Skipping replay #1853 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1853 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1862/3456 | Loaded  53.88% | Elapsed 00h28m26s
# Skipping replay #1861 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1861 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1865/3456 | Loaded  53.96% | Elapsed 00h28m27s
# Skipping replay #1864 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #1864 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1867/3456 | Loaded  54.02% | Elapsed 00h28m28s
# Skipping replay #1866 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #
due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 2058/3456 | Loaded  59.55% | Elapsed 00h31m34s
# Skipping replay #2057 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #2057 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 2060/3456 | Loaded  59.61% | Elapsed 00h31m35s
# Skipping replay #2059 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #2059 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 2062/3456 | Loaded  59.66% | Elapsed 00h31m35s
# Skipping replay #2061 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #2061 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 2064/3456 | Loaded  59.72% | Elapsed 00h31m36s
# Skipping replay #2063 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #2063 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 2066/3456 | Loaded  59.78% | Elapsed 00h31m38s
# Skipping replay #2065 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #2065 due to thrown exception.
# 'R'
# Loading replay 2069/3456 | Loaded  59.87% | Elapsed 00h31m39s
# Skipping replay #2068 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #2068 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 2071/3456 | Loaded  59.92% | Elapsed 00h31m39s
# Skipping replay #2070 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #2070 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 2080/3456 | Loaded  60.19% | Elapsed 00h31m44s
# Skipping replay #2079 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #2079 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 2082/3456 | Loaded  60.24% | Elapsed 00h31m45s
# Skipping replay #2081 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #2081 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 2091/3456 | Loaded  60.50% | Elapsed 00h31m49s
# Skipping replay #2090 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
#
# Skipping replay #2090 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 3456/3456 | Loaded 100.00% | Elapsed 01h02m56s
#
# END: Found {'P': 2308, 'T': 1984, 'Z': 2482} valid games (total=6774) out of 3456.

# %%
for k in dfs.keys():
    tmp_df = dfs[k] # grab a dataset by its player 1's race

    # go through all quantitative columns and check if their values are < 0
    # meaning it will return true if they are negative
    # then, since True == 1 and False == 0, get the result of summation per column
    negative_check = tmp_df[tmp_df.select_dtypes(exclude=['object']) < 0].sum()
    # only keep columns that are actually negative
    negative_check = negative_check[negative_check < 0]

    # this is not necessary
    # I just like how nice it looks
    col_negative_sum_zip = list(zip(negative_check.index.to_list(), negative_check.to_list()))
    if len(col_negative_sum_zip) > 0:
        col_negative_sum_zip = '\n'.join(['{} {}'.format(*n) for n in col_negative_sum_zip])
    else:
        col_negative_sum_zip = None

    print('Negative total by column for {}:\n  {}\n'.format(k, col_negative_sum_zip))
# Out:
# Negative total by column for P:
#   None
#
# Negative total by column for T:
#   orbitalcommand -83.0
#
# Negative total by column for Z:
#   None

# %%
name_map = {
    'T': 'terran',
    'P': 'protoss',
    'Z': 'zerg'
}

for k in dfs.keys():
    # get the race name by key map
    name = name_map[k]

    # only generate dataset csv if it actually contains stuff
    if len(dfs[k]) == 0:
        print('Dataframe for {} is empty, so skipping.'.format(name))
        continue

    tmp_df = dfs[k] # grab a dataset by its player 1's race

    # we're storing the number of matches stored in each dataframe
    # so, get its respective total match count by its race
    total_matches = hr.valid_matches[k]
    # create a date string for the current time and date
    date_str = datetime.datetime.now().strftime('%b-%d-%Y_%H%M%S').lower()
    # create a descriptive csv file name with:
    # - player 1's race
    # - the number of matches it contains
    # - when the dataset was generated
    filename = '{}_{}_{}'.format(name, total_matches, date_str)
    path = '../data/processed/{}.csv'.format(filename)

    print('Saving as', path)
    tmp_df.to_csv(path)
# Out:
# Saving as ../data/processed/protoss_2308_feb-08-2021_165940.csv
# Saving as ../data/processed/terran_1984_feb-08-2021_165941.csv
# Saving as ../data/processed/zerg_2482_feb-08-2021_165942.csv
