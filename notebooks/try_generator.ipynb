# %%
import sys
sys.path.append('..') # goes to project root

from preparation.generators.Generator import Generator
from IPython.display import display
import pandas as pd
import datetime
import json

pd.options.display.max_columns = None

# %%
# our Generator object requires one parameter
# grab the attr_map and load it in as a dictionary
with open('../data/functional/races.json', 'rb') as f:
    attr_map = json.load(f)

# instantiate a dataset Generator object
hr = Generator(attr_map=attr_map)

# %%
# loads replay references into memory
dfs = hr.load_replays('../data/raw/**/*.SC2Replay', limit=None)
# Out:
# Loaded 3456 replays out of 3456.

# %%
# We're storing all dataframes by key
# Keys are P, T, and Z
# These represent each race
dfs = hr.getData(verbose=False)
# Out:
# Loading replay 1477/3456 | Loaded  42.74% | Elapsed 00h22m43sSkipping replay #1476 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1486/3456 | Loaded  43.00% | Elapsed 00h22m53sSkipping replay #1485 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1491/3456 | Loaded  43.14% | Elapsed 00h22m57sSkipping replay #1490 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1497/3456 | Loaded  43.32% | Elapsed 00h23m02sSkipping replay #1496 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1770/3456 | Loaded  51.22% | Elapsed 00h26m30sSkipping replay #1769 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1776/3456 | Loaded  51.39% | Elapsed 00h26m33sSkipping replay #1775 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1780/3456 | Loaded  51.50% | Elapsed 00h26m34sSkipping replay #1779 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1783/3456 | Loaded  51.59% | Elapsed 00h26m36sSkipping replay #1782 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1792/3456 | Loaded  51.85% | Elapsed 00h26m39sSkipping replay #1791 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1794/3456 | Loaded  51.91% | Elapsed 00h26m40sSkipping replay #1793 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1795/3456 | Loaded  51.94% | Elapsed 00h26m40sSkipping replay #1794 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1801/3456 | Loaded  52.11% | Elapsed 00h26m42sSkipping replay #1800 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1806/3456 | Loaded  52.26% | Elapsed 00h26m43sSkipping replay #1805 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1808/3456 | Loaded  52.31% | Elapsed 00h27m43sSkipping replay #1807 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1815/3456 | Loaded  52.52% | Elapsed 00h27m46sSkipping replay #1814 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1822/3456 | Loaded  52.72% | Elapsed 00h27m48sSkipping replay #1821 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1823/3456 | Loaded  52.75% | Elapsed 00h27m49sSkipping replay #1822 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1826/3456 | Loaded  52.84% | Elapsed 00h27m50sSkipping replay #1825 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1839/3456 | Loaded  53.21% | Elapsed 00h27m56sSkipping replay #1838 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1841/3456 | Loaded  53.27% | Elapsed 00h27m57sSkipping replay #1840 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1842/3456 | Loaded  53.30% | Elapsed 00h27m57sSkipping replay #1841 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1843/3456 | Loaded  53.33% | Elapsed 00h27m58sSkipping replay #1842 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1854/3456 | Loaded  53.65% | Elapsed 00h28m02sSkipping replay #1853 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1862/3456 | Loaded  53.88% | Elapsed 00h28m04sSkipping replay #1861 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1865/3456 | Loaded  53.96% | Elapsed 00h28m05sSkipping replay #1864 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1867/3456 | Loaded  54.02% | Elapsed 00h28m06sSkipping replay #1866 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1871/3456 | Loaded  54.14% | Elapsed 00h28m08sSkipping replay #1870 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1876/3456 | Loaded  54.28% | Elapsed 00h28m09sSkipping replay #1875 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1885/3456 | Loaded  54.54% | Elapsed 00h28m14sSkipping replay #1884 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1889/3456 | Loaded  54.66% | Elapsed 00h28m18sSkipping replay #1888 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1895/3456 | Loaded  54.83% | Elapsed 00h28m21sSkipping replay #1894 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1901/3456 | Loaded  55.01% | Elapsed 00h28m26sSkipping replay #1900 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1904/3456 | Loaded  55.09% | Elapsed 00h28m28sSkipping replay #1903 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1907/3456 | Loaded  55.18% | Elapsed 00h28m29sSkipping replay #1906 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1909/3456 | Loaded  55.24% | Elapsed 00h28m34sSkipping replay #1908 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1913/3456 | Loaded  55.35% | Elapsed 00h28m36sSkipping replay #1912 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1915/3456 | Loaded  55.41% | Elapsed 00h28m38sSkipping replay #1914 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1917/3456 | Loaded  55.47% | Elapsed 00h28m39sSkipping replay #1916 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1924/3456 | Loaded  55.67% | Elapsed 00h28m44sSkipping replay #1923 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1927/3456 | Loaded  55.76% | Elapsed 00h28m45sSkipping replay #1926 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1928/3456 | Loaded  55.79% | Elapsed 00h28m46sSkipping replay #1927 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1932/3456 | Loaded  55.90% | Elapsed 00h28m49sSkipping replay #1931 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1933/3456 | Loaded  55.93% | Elapsed 00h28m50sSkipping replay #1932 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1937/3456 | Loaded  56.05% | Elapsed 00h28m51sSkipping replay #1936 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1943/3456 | Loaded  56.22% | Elapsed 00h28m54sSkipping replay #1942 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1951/3456 | Loaded  56.45% | Elapsed 00h28m59sSkipping replay #1950 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1961/3456 | Loaded  56.74% | Elapsed 00h29m09sSkipping replay #1960 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1963/3456 | Loaded  56.80% | Elapsed 00h29m10sSkipping replay #1962 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1965/3456 | Loaded  56.86% | Elapsed 00h29m12sSkipping replay #1964 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1968/3456 | Loaded  56.94% | Elapsed 00h29m13sSkipping replay #1967 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1977/3456 | Loaded  57.20% | Elapsed 00h29m17sSkipping replay #1976 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1983/3456 | Loaded  57.38% | Elapsed 00h29m20sSkipping replay #1982 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 1996/3456 | Loaded  57.75% | Elapsed 00h29m26sSkipping replay #1995 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 2020/3456 | Loaded  58.45% | Elapsed 00h29m33sSkipping replay #2019 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 2024/3456 | Loaded  58.56% | Elapsed 00h29m34sSkipping replay #2023 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 2029/3456 | Loaded  58.71% | Elapsed 00h29m36sSkipping replay #2028 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 2042/3456 | Loaded  59.09% | Elapsed 00h30m52sSkipping replay #2041 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 2053/3456 | Loaded  59.40% | Elapsed 00h30m58sSkipping replay #2052 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 2056/3456 | Loaded  59.49% | Elapsed 00h30m59sSkipping replay #2055 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 2058/3456 | Loaded  59.55% | Elapsed 00h31m01sSkipping replay #2057 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 2060/3456 | Loaded  59.61% | Elapsed 00h31m02sSkipping replay #2059 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 2062/3456 | Loaded  59.66% | Elapsed 00h31m03sSkipping replay #2061 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 2064/3456 | Loaded  59.72% | Elapsed 00h31m04sSkipping replay #2063 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 2066/3456 | Loaded  59.78% | Elapsed 00h31m05sSkipping replay #2065 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 2069/3456 | Loaded  59.87% | Elapsed 00h31m06sSkipping replay #2068 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 2071/3456 | Loaded  59.92% | Elapsed 00h31m07sSkipping replay #2070 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 2080/3456 | Loaded  60.19% | Elapsed 00h31m10sSkipping replay #2079 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 2082/3456 | Loaded  60.24% | Elapsed 00h31m12sSkipping replay #2081 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 2091/3456 | Loaded  60.50% | Elapsed 00h31m15sSkipping replay #2090 due to thrown exception.
# 'NoneType' object has no attribute 'lower'
# Loading replay 3456/3456 | Loaded 100.00% | Elapsed 01h03m27s
#
# END: Found {'P': 1103, 'T': 1018, 'Z': 1266} valid games (total=3387) out of 3456.

# %%
for k in dfs.keys():
    tmp_df = dfs[k] # grab a dataset by its player 1's race

    # go through all quantitative columns and check if their values are < 0
    # meaning it will return true if they are negative
    # then, since True == 1 and False == 0, get the result of summation per column
    negative_check = tmp_df[tmp_df.select_dtypes(exclude=['object']) < 0].sum()
    # only keep columns that are actually negative
    negative_check = negative_check[negative_check < 0]

    # this is not necessary
    # I just like how nice it looks
    col_negative_sum_zip = list(zip(negative_check.index.to_list(), negative_check.to_list()))
    if len(col_negative_sum_zip) > 0:
        col_negative_sum_zip = '\n'.join(['{} {}'.format(*n) for n in col_negative_sum_zip])
    else:
        col_negative_sum_zip = None

    print('Negative total by column for {}:\n  {}\n'.format(k, col_negative_sum_zip))
# Out:
# Negative total by column for P:
#   None
#
# Negative total by column for T:
#   orbitalcommand -56.0
#
# Negative total by column for Z:
#   None

# %%
name_map = {
    'T': 'terran',
    'P': 'protoss',
    'Z': 'zerg'
}

for k in dfs.keys():
    # get the race name by key map
    name = name_map[k]

    # only generate dataset csv if it actually contains stuff
    if len(dfs[k]) == 0:
        print('Dataframe for {} is empty, so skipping.'.format(name))
        continue

    tmp_df = dfs[k] # grab a dataset by its player 1's race

    # we're storing the number of matches stored in each dataframe
    # so, get its respective total match count by its race
    total_matches = hr.valid_matches[k]
    # create a date string for the current time and date
    date_str = datetime.datetime.now().strftime('%b-%d-%Y_%H%M%S').lower()
    # create a descriptive csv file name with:
    # - player 1's race
    # - the number of matches it contains
    # - when the dataset was generated
    filename = '{}_{}_{}'.format(name, total_matches, date_str)
    path = '../data/processed/{}.csv'.format(filename)

    print('Saving as', path)
    tmp_df.to_csv(path)
# Out:
# Saving as ../data/processed/protoss_1103_jan-25-2021_144934.csv
# Saving as ../data/processed/terran_1018_jan-25-2021_144934.csv
# Saving as ../data/processed/zerg_1266_jan-25-2021_144935.csv
